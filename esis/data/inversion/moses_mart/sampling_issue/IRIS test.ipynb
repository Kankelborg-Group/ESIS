# %% [markdown]
# # Testing MART with IRIS data
# My experimentation in the [SimplePlaid notebook](SimplePlaid.ipynb) showed that the _Smooth_ part of my ancient SMART algorithm, and its complicated control law, were quite unnecessary. I now have a simple and streamlined vanilla MART. Now, however, a number of things have to be worked out before MART reaches its full potential.
# 1. Can I improve results by increasing contrast to minimize the entropy? There are persistent hints that some such regularization scheme might help, but results with very fake test targets may not give the insight I really need. My crude attempts at regularization so far have been dismal failures.
# 2. What initial guess should I use? I experimented with that years ago, and found a strong prior for the line core was helpful.
#
# I have stored Roy's IRIS training dataset (retrieved December, 2018) as `roy-iris-cube.pickle`. Below I experiment with slice 175, containing an explosive event that I have dubbed the Crucifix. This potentially clarifies some of the above questions and adds some more:
# 3. Starting with an initial guess that looks kind of like $I_{\infty}$, a tight line core with some background, not only improves the result but gives more rapid convergence by a factor of 10.
# 4. Just guessing, but I suspect the residuals are much worse in the neighborhood of the EEs at approx. $x=25$ and $x=65$. I hypothesize that  a position-dependent, rather than a global, goodness of fit would be worth putting into MART.

# %%
# Load Roy's data cube
import pickle
infile = open('roy-iris-cube.pickle','rb')
cube = pickle.load(infile)
infile.close()
print('cube shape: ',cube.shape)
# Out:
# cube shape:  (1831, 200, 21, 1)

# %%
# Example: the crucifix
import numpy as np
import moses
import matplotlib.pyplot as plt
Npad = 3 # for padding in the lambda direction
ExplosiveEvent0 =   33 # first index of cube, to get an alternative explosive event.
ExplosiveEvent1 =  121 # first index of cube, to get an alternative explosive event.
ExplosiveEvent2 =  175 # first index of cube, to get the 'crucifix' explosive event. *** my favorite.
ExplosiveEvent3 = 1015 # first index of cube, to get an alternative explosive event.
I = moses.zpad(cube[ExplosiveEvent2,:,:,0], Npad)
    # Different slices of the cube can be tried by replacing the first index to get
    # any slice in the cube. The above explosive events are particularly useful examples.
I = (I + np.abs(I))/2
print('I shape: ',I.shape)
print('I min mean max = ',np.amin(I),np.mean(I),np.amax(I))
Nx = I.shape[0]
Nlambda = I.shape[1]
j0 = int(np.floor(Nlambda/2.))
# Out:
# I shape:  (200, 27)
# I min mean max =  0.0 18.201157407407408 450.25

# %%
# Calculate data with Poisson noise
import moses
I *= 10 # more counts
Dp = np.random.poisson(moses.fomod(I, 1,j0)).astype(float)
D0 = np.random.poisson(moses.fomod(I, 0,j0)).astype(float)
Dm = np.random.poisson(moses.fomod(I,-1,j0)).astype(float)
print('Crucifix mean signal = ',np.mean(Dp))

# Simple MART
DataArr = np.array([D0,Dp,Dm])
mArr = np.array([0,1,-1])
Gmart = moses.mart(DataArr, mArr, Nlambda, j0, maxiter=3000)
# Out:
# Crucifix mean signal =  4916.665
# outeration  1  of, at most,  1
# MART iteration  1  of, at most,  3000
# 0  order "reduced chisquare" =  3956.3510154332366
# 1  order "reduced chisquare" =  738.487513687336
# -1  order "reduced chisquare" =  560.3694633309664
# MART iteration  2  of, at most,  3000
# 0  order "reduced chisquare" =  86.96981783485626
# 1  order "reduced chisquare" =  54.921225582575765
# -1  order "reduced chisquare" =  66.76499092400807
# MART iteration  3  of, at most,  3000
# 0  order "reduced chisquare" =  38.41113061233728
# 1  order "reduced chisquare" =  20.703070702481458
# -1  order "reduced chisquare" =  22.53161666499729
# MART iteration  4  of, at most,  3000
# 0  order "reduced chisquare" =  28.580585962284328
# 1  order "reduced chisquare" =  13.396109654663388
# -1  order "reduced chisquare" =  13.703796507321629
# MART iteration  5  of, at most,  3000
# 0  order "reduced chisquare" =  23.90942344273372
# 1  order "reduced chisquare" =  10.302880562128985
# -1  order "reduced chisquare" =  10.468287569382301
# MART iteration  6  of, at most,  3000
# 0  order "reduced chisquare" =  21.06565430455153
# 1  order "reduced chisquare" =  8.54474637865816
# -1  order "reduced chisquare" =  8.711444121717966
# MART iteration  7  of, at most,  3000
# 0  order "reduced chisquare" =  19.048308723840684
# 1  order "reduced chisquare" =  7.387960798481041
# -1  order "reduced chisquare" =  7.563140521994352
# MART iteration  8  of, at most,  3000
# 0  order "reduced chisquare" =  17.494302295669055
# 1  order "reduced chisquare" =  6.560995377092999
# -1  order "reduced chisquare" =  6.741778369505332
# MART iteration  9  of, at most,  3000
# 0  order "reduced chisquare" =  16.24251778681314
# 1  order "reduced chisquare" =  5.938197362406048
# -1  order "reduced chisquare" =  6.121575103269062
# MART iteration  10  of, at most,  3000
# 0  order "reduced chisquare" =  15.205795035986341
# 1  order "reduced chisquare" =  5.45162532790145
# -1  order "reduced chisquare" =  5.634847788063871
# MART iteration  11  of, at most,  3000
# 0  order "reduced chisquare" =  14.32979179781854
# 1  order "reduced chisquare" =  5.060471996551805
# -1  order "reduced chisquare" =  5.2412086996604375
# MART iteration  12  of, at most,  3000
# 0  order "reduced chisquare" =  13.577570159571218
# 1  order "reduced chisquare" =  4.738486860745659
# -1  order "reduced chisquare" =  4.914942298334162
# MART iteration  13  of, at most,  3000
# 0  order "reduced chisquare" =  12.922708160440168
# 1  order "reduced chisquare" =  4.467987839794837
# -1  order "reduced chisquare" =  4.638897297770487
# MART iteration  14  of, at most,  3000
# 0  order "reduced chisquare" =  12.345693981152326
# 1  order "reduced chisquare" =  4.236664512888399
# -1  order "reduced chisquare" =  4.401216183249326
# MART iteration  15  of, at most,  3000
# 0  order "reduced chisquare" =  11.831800992560266
# 1  order "reduced chisquare" =  4.035725552406617
# -1  order "reduced chisquare" =  4.193460973990024
# MART iteration  16  of, at most,  3000
# 0  order "reduced chisquare" =  11.3697310977112
# 1  order "reduced chisquare" =  3.8587614911816672
# -1  order "reduced chisquare" =  4.009482658642095
# MART iteration  17  of, at most,  3000
# 0  order "reduced chisquare" =  10.95070158583131
# 1  order "reduced chisquare" =  3.7010168315942193
# -1  order "reduced chisquare" =  3.8447101304230915
# MART iteration  18  of, at most,  3000
# 0  order "reduced chisquare" =  10.567807940146208
# 1  order "reduced chisquare" =  3.558908947798697
# -1  order "reduced chisquare" =  3.695686908349273
# MART iteration  19  of, at most,  3000
# 0  order "reduced chisquare" =  10.215567483930096
# 1  order "reduced chisquare" =  3.4297017114776507
# -1  order "reduced chisquare" =  3.5597600759934322
# MART iteration  20  of, at most,  3000
# 0  order "reduced chisquare" =  9.889586022992411
# 1  order "reduced chisquare" =  3.3112791861550797
# -1  order "reduced chisquare" =  3.4348659997745226
# MART iteration  21  of, at most,  3000
# 0  order "reduced chisquare" =  9.586310527836606
# 1  order "reduced chisquare" =  3.201985755616083
# -1  order "reduced chisquare" =  3.319379475229373
# MART iteration  22  of, at most,  3000
# 0  order "reduced chisquare" =  9.30284335198238
# 1  order "reduced chisquare" =  3.1005113674335525
# -1  order "reduced chisquare" =  3.212005566955511
# MART iteration  23  of, at most,  3000
# 0  order "reduced chisquare" =  9.036801256064964
# 1  order "reduced chisquare" =  3.005808027935233
# -1  order "reduced chisquare" =  3.111700860882324
# MART iteration  24  of, at most,  3000
# 0  order "reduced chisquare" =  8.786207534496896
# 1  order "reduced chisquare" =  2.917028323754836
# -1  order "reduced chisquare" =  3.0176153876668947
# MART iteration  25  of, at most,  3000
# 0  order "reduced chisquare" =  8.549408889689865
# 1  order "reduced chisquare" =  2.8334797030165904
# -1  order "reduced chisquare" =  2.929049322319115
# MART iteration  26  of, at most,  3000
# 0  order "reduced chisquare" =  8.325010986284365
# 1  order "reduced chisquare" =  2.7545901784858415
# -1  order "reduced chisquare" =  2.8454203980721515
# MART iteration  27  of, at most,  3000
# 0  order "reduced chisquare" =  8.111828215978196
# 1  order "reduced chisquare" =  2.67988240028112
# -1  order "reduced chisquare" =  2.766239182530346
# MART iteration  28  of, at most,  3000
# 0  order "reduced chisquare" =  7.908844342192747
# 1  order "reduced chisquare" =  2.608953918925165
# -1  order "reduced chisquare" =  2.6910901812549315
# MART iteration  29  of, at most,  3000
# 0  order "reduced chisquare" =  7.715181518866668
# 1  order "reduced chisquare" =  2.541462063447793
# -1  order "reduced chisquare" =  2.6196172970920784
# MART iteration  30  of, at most,  3000
# 0  order "reduced chisquare" =  7.530075784011358
# 1  order "reduced chisquare" =  2.477112283706782
# -1  order "reduced chisquare" =  2.551512568652099
# MART iteration  31  of, at most,  3000
# 0  order "reduced chisquare" =  7.3528575795041045
# 1  order "reduced chisquare" =  2.415649108629721
# -1  order "reduced chisquare" =  2.4865073928680017
# MART iteration  32  of, at most,  3000
# 0  order "reduced chisquare" =  7.182936186985014
# 1  order "reduced chisquare" =  2.356849090349991
# -1  order "reduced chisquare" =  2.4243656398001114
# MART iteration  33  of, at most,  3000
# 0  order "reduced chisquare" =  7.019787225626978
# 1  order "reduced chisquare" =  2.3005152633229646
# -1  order "reduced chisquare" =  2.364878216204657
# MART iteration  34  of, at most,  3000
# 0  order "reduced chisquare" =  6.862942552229057
# 1  order "reduced chisquare" =  2.246472764514395
# -1  order "reduced chisquare" =  2.3078587436725724
# MART iteration  35  of, at most,  3000
# 0  order "reduced chisquare" =  6.711982052888175
# 1  order "reduced chisquare" =  2.19456534742833
# -1  order "reduced chisquare" =  2.2531400982729757
# MART iteration  36  of, at most,  3000
# 0  order "reduced chisquare" =  6.566526929674541
# 1  order "reduced chisquare" =  2.1446525873462865
# -1  order "reduced chisquare" =  2.2005716192443265
# MART iteration  37  of, at most,  3000
# 0  order "reduced chisquare" =  6.426234173599592
# 1  order "reduced chisquare" =  2.0966076235544655
# -1  order "reduced chisquare" =  2.1500168397976775
# MART iteration  38  of, at most,  3000
# 0  order "reduced chisquare" =  6.290791982959348
# 1  order "reduced chisquare" =  2.0503153207634637
# -1  order "reduced chisquare" =  2.1013516274397346
# MART iteration  39  of, at most,  3000
# 0  order "reduced chisquare" =  6.159915938557318
# 1  order "reduced chisquare" =  2.0056707594445986
# -1  order "reduced chisquare" =  2.0544626472360257
# MART iteration  40  of, at most,  3000
# 0  order "reduced chisquare" =  6.033345787928305
# 1  order "reduced chisquare" =  1.9625779856664067
# -1  order "reduced chisquare" =  2.009246081202752
# MART iteration  41  of, at most,  3000
# 0  order "reduced chisquare" =  5.910842722213081
# 1  order "reduced chisquare" =  1.9209489668734008
# -1  order "reduced chisquare" =  1.965606552086914
# MART iteration  42  of, at most,  3000
# 0  order "reduced chisquare" =  5.792187053852854
# 1  order "reduced chisquare" =  1.8807027121396627
# -1  order "reduced chisquare" =  1.9234562113152225
# MART iteration  43  of, at most,  3000
# 0  order "reduced chisquare" =  5.6771762223763
# 1  order "reduced chisquare" =  1.8417645246708583
# -1  order "reduced chisquare" =  1.882713959724934
# MART iteration  44  of, at most,  3000
# 0  order "reduced chisquare" =  5.565623070464444
# 1  order "reduced chisquare" =  1.804065361410434
# -1  order "reduced chisquare" =  1.843304776478006
# MART iteration  45  of, at most,  3000
# 0  order "reduced chisquare" =  5.457354344145452
# 1  order "reduced chisquare" =  1.7675412800458912
# -1  order "reduced chisquare" =  1.8051591367922037
# MART iteration  46  of, at most,  3000
# 0  order "reduced chisquare" =  5.352209380117878
# 1  order "reduced chisquare" =  1.732132957901908
# -1  order "reduced chisquare" =  1.7682125031660554
# MART iteration  47  of, at most,  3000
# 0  order "reduced chisquare" =  5.2500389503911205
# 1  order "reduced chisquare" =  1.6977852704435432
# -1  order "reduced chisquare" =  1.7324048779082302
# MART iteration  48  of, at most,  3000
# 0  order "reduced chisquare" =  5.150704240098113
# 1  order "reduced chisquare" =  1.6644469196195797
# -1  order "reduced chisquare" =  1.6976804072186706
# MART iteration  49  of, at most,  3000
# 0  order "reduced chisquare" =  5.0540759388156085
# 1  order "reduced chisquare" =  1.6320701042240628
# -1  order "reduced chisquare" =  1.663987028969161
# MART iteration  50  of, at most,  3000
# 0  order "reduced chisquare" =  4.960033429280747
# 1  order "reduced chisquare" =  1.6006102259726191
# -1  order "reduced chisquare" =  1.631276157819248
# MART iteration  51  of, at most,  3000
# 0  order "reduced chisquare" =  4.868464060221824
# 1  order "reduced chisquare" =  1.5700256261783159
# -1  order "reduced chisquare" =  1.5995024024728373
# MART iteration  52  of, at most,  3000
# 0  order "reduced chisquare" =  4.779262492282835
# 1  order "reduced chisquare" =  1.5402773488459325
# -1  order "reduced chisquare" =  1.568623310804291
# MART iteration  53  of, at most,  3000
# 0  order "reduced chisquare" =  4.692330107836705
# 1  order "reduced chisquare" =  1.5113289267400387
# -1  order "reduced chisquare" =  1.5385991393152352
# MART iteration  54  of, at most,  3000
# 0  order "reduced chisquare" =  4.607574476947657
# 1  order "reduced chisquare" =  1.4831461875673477
# -1  order "reduced chisquare" =  1.5093926439672218
# MART iteration  55  of, at most,  3000
# 0  order "reduced chisquare" =  4.5249088729303555
# 1  order "reduced chisquare" =  1.4556970778795502
# -1  order "reduced chisquare" =  1.4809688899037923
# MART iteration  56  of, at most,  3000
# 0  order "reduced chisquare" =  4.444251831922248
# 1  order "reduced chisquare" =  1.4289515026772792
# -1  order "reduced chisquare" =  1.4532950779530602
# MART iteration  57  of, at most,  3000
# 0  order "reduced chisquare" =  4.365526751680099
# 1  order "reduced chisquare" =  1.4028811789976847
# -1  order "reduced chisquare" =  1.4263403861088175
# MART iteration  58  of, at most,  3000
# 0  order "reduced chisquare" =  4.288661525466423
# 1  order "reduced chisquare" =  1.377459502013359
# -1  order "reduced chisquare" =  1.4000758244389417
# MART iteration  59  of, at most,  3000
# 0  order "reduced chisquare" =  4.21358820743639
# 1  order "reduced chisquare" =  1.3526614223717919
# -1  order "reduced chisquare" =  1.3744741020760562
# MART iteration  60  of, at most,  3000
# 0  order "reduced chisquare" =  4.140242706389986
# 1  order "reduced chisquare" =  1.3284633336697151
# -1  order "reduced chisquare" =  1.3495095051171229
# MART iteration  61  of, at most,  3000
# 0  order "reduced chisquare" =  4.0685645051370605
# 1  order "reduced chisquare" =  1.3048429690951013
# -1  order "reduced chisquare" =  1.3251577844014515
# MART iteration  62  of, at most,  3000
# 0  order "reduced chisquare" =  3.998496403046546
# 1  order "reduced chisquare" =  1.2817793063845242
# -1  order "reduced chisquare" =  1.3013960522571788
# MART iteration  63  of, at most,  3000
# 0  order "reduced chisquare" =  3.9299842796272526
# 1  order "reduced chisquare" =  1.2592524803413903
# -1  order "reduced chisquare" =  1.2782026874088779
# MART iteration  64  of, at most,  3000
# 0  order "reduced chisquare" =  3.8629768772242477
# 1  order "reduced chisquare" =  1.2372437022434355
# -1  order "reduced chisquare" =  1.255557247325955
# MART iteration  65  of, at most,  3000
# 0  order "reduced chisquare" =  3.797425601119144
# 1  order "reduced chisquare" =  1.2157351855390184
# -1  order "reduced chisquare" =  1.2334403873671256
# MART iteration  66  of, at most,  3000
# 0  order "reduced chisquare" =  3.7332843354997247
# 1  order "reduced chisquare" =  1.1947100772930912
# -1  order "reduced chisquare" =  1.2118337861414112
# MART iteration  67  of, at most,  3000
# 0  order "reduced chisquare" =  3.6705092739192082
# 1  order "reduced chisquare" =  1.174152394897439
# -1  order "reduced chisquare" =  1.190720076562976
# MART iteration  68  of, at most,  3000
# 0  order "reduced chisquare" =  3.6090587630009856
# 1  order "reduced chisquare" =  1.1540469676061802
# -1  order "reduced chisquare" =  1.1700827821272175
# MART iteration  69  of, at most,  3000
# 0  order "reduced chisquare" =  3.548893158264515
# 1  order "reduced chisquare" =  1.134379382499101
# -1  order "reduced chisquare" =  1.1499062579795152
# MART iteration  70  of, at most,  3000
# 0  order "reduced chisquare" =  3.4899746910536624
# 1  order "reduced chisquare" =  1.1151359345115288
# -1  order "reduced chisquare" =  1.1301756363872624
# MART iteration  71  of, at most,  3000
# 0  order "reduced chisquare" =  3.432267345643425
# 1  order "reduced chisquare" =  1.0963035802020837
# -1  order "reduced chisquare" =  1.1108767762606468
# MART iteration  72  of, at most,  3000
# 0  order "reduced chisquare" =  3.375736745684682
# 1  order "reduced chisquare" =  1.0778698949586663
# -1  order "reduced chisquare" =  1.0919962163987085
# MART iteration  73  of, at most,  3000
# 0  order "reduced chisquare" =  3.3203500492218723
# 1  order "reduced chisquare" =  1.0598230333688021
# -1  order "reduced chisquare" =  1.0735211321654794
# MART iteration  74  of, at most,  3000
# 0  order "reduced chisquare" =  3.266075851586346
# 1  order "reduced chisquare" =  1.0421516925042613
# -1  order "reduced chisquare" =  1.0554392953259133
# MART iteration  75  of, at most,  3000
# 0  order "reduced chisquare" =  3.212884095528842
# 1  order "reduced chisquare" =  1.0248450778906248
# -1  order "reduced chisquare" =  1.0377390367944315
# MART iteration  76  of, at most,  3000
# 0  order "reduced chisquare" =  3.1607459880094906
# 1  order "reduced chisquare" =  1.0078928719519737
# -1  order "reduced chisquare" =  1.0204092120692891
# MART iteration  77  of, at most,  3000
# 0  order "reduced chisquare" =  3.1096339231134187
# 1  order "reduced chisquare" =  0.9912852047379596
# -1  order "reduced chisquare" =  1.8050312764142837
# MART iteration  78  of, at most,  3000
# 0  order "reduced chisquare" =  1.8901271303255271
# 1  order "reduced chisquare" =  1.7176977138503147
# -1  order "reduced chisquare" =  0.6250264701914355
# MART iteration  79  of, at most,  3000
# 0  order "reduced chisquare" =  1.4793090074514519
# 1  order "reduced chisquare" =  1.2816599897470504
# -1  order "reduced chisquare" =  1.1899261444566542
# MART iteration  80  of, at most,  3000
# 0  order "reduced chisquare" =  2.8823248401239927
# 1  order "reduced chisquare" =  0.9561853225726412
# -1  order "reduced chisquare" =  1.7745932295998659
# MART iteration  81  of, at most,  3000
# 0  order "reduced chisquare" =  1.8121632917984993
# 1  order "reduced chisquare" =  1.6404009014612257
# -1  order "reduced chisquare" =  0.6081031887831203
# MART iteration  82  of, at most,  3000
# 0  order "reduced chisquare" =  1.4163357288735694
# 1  order "reduced chisquare" =  1.227380340932637
# -1  order "reduced chisquare" =  1.1513344332516404
# MART iteration  83  of, at most,  3000
# 0  order "reduced chisquare" =  2.7703567232503015
# 1  order "reduced chisquare" =  0.9165032070083143
# -1  order "reduced chisquare" =  1.70981695936373
# MART iteration  84  of, at most,  3000
# 0  order "reduced chisquare" =  1.7447411729467177
# 1  order "reduced chisquare" =  1.5720554254925754
# -1  order "reduced chisquare" =  0.5862630730444262
# MART iteration  85  of, at most,  3000
# 0  order "reduced chisquare" =  1.3604661645905372
# 1  order "reduced chisquare" =  1.1789953932105988
# -1  order "reduced chisquare" =  1.107666868039682
# MART iteration  86  of, at most,  3000
# 0  order "reduced chisquare" =  2.663498913053622
# 1  order "reduced chisquare" =  0.8805756264472513
# -1  order "reduced chisquare" =  1.645663226336593
# MART iteration  87  of, at most,  3000
# 0  order "reduced chisquare" =  1.6791388568894143
# 1  order "reduced chisquare" =  1.5091758228955765
# -1  order "reduced chisquare" =  0.5639844521364791
# MART iteration  88  of, at most,  3000
# 0  order "reduced chisquare" =  1.3080204492731986
# 1  order "reduced chisquare" =  1.1339084440654685
# -1  order "reduced chisquare" =  1.064056546203565
# MART iteration  89  of, at most,  3000
# 0  order "reduced chisquare" =  2.5614259426681714
# 1  order "reduced chisquare" =  0.8468945828612544
# -1  order "reduced chisquare" =  1.583664321159619
# MART iteration  90  of, at most,  3000
# 0  order "reduced chisquare" =  1.6160696335298224
# 1  order "reduced chisquare" =  1.4499334077462236
# -1  order "reduced chisquare" =  0.5422354336493648
# MART iteration  91  of, at most,  3000
# 0  order "reduced chisquare" =  1.2582433169184473
# 1  order "reduced chisquare" =  1.0912122764308014
# -1  order "reduced chisquare" =  1.0218016520429047
# MART iteration  92  of, at most,  3000
# 0  order "reduced chisquare" =  2.4639412193684502
# 1  order "reduced chisquare" =  0.8149292191066648
# -1  order "reduced chisquare" =  1.5241828155623838
# MART iteration  93  of, at most,  3000
# 0  order "reduced chisquare" =  1.5556729672681948
# 1  order "reduced chisquare" =  1.3936500063398107
# -1  order "reduced chisquare" =  0.5213109318345265
# MART iteration  94  of, at most,  3000
# 0  order "reduced chisquare" =  1.2107913681948252
# 1  order "reduced chisquare" =  1.0505275478268163
# -1  order "reduced chisquare" =  0.981280207397771
# MART iteration  95  of, at most,  3000
# 0  order "reduced chisquare" =  0.9348304851492574
# 1  order "reduced chisquare" =  0.11671893766349513
# -1  order "reduced chisquare" =  0.981280207397771

# %%
# Give simple MART a better start?
G_initial = moses.window((Nx,Nlambda))**40 + 0.05 # Line core plus background
GmartPrecon = moses.mart(DataArr, mArr, Nlambda, j0, maxiter=2000, InitGuess=G_initial, LGOF=False)
# Out:
# outeration  1  of, at most,  1
# MART iteration  1  of, at most,  2000
# 0  order "reduced chisquare" =  6983382.62639587
# 1  order "reduced chisquare" =  45482.618498029056
# -1  order "reduced chisquare" =  3817.504727133035
# MART iteration  2  of, at most,  2000
# 0  order "reduced chisquare" =  490.4228072648522
# 1  order "reduced chisquare" =  70.80112844769346
# -1  order "reduced chisquare" =  71.21122725511975
# MART iteration  3  of, at most,  2000
# 0  order "reduced chisquare" =  41.245865355126334
# 1  order "reduced chisquare" =  8.36833982637021
# -1  order "reduced chisquare" =  24.988055312639535
# MART iteration  4  of, at most,  2000
# 0  order "reduced chisquare" =  17.339585957469662
# 1  order "reduced chisquare" =  2.9856313596501876
# -1  order "reduced chisquare" =  10.76923152418733
# MART iteration  5  of, at most,  2000
# 0  order "reduced chisquare" =  8.113426287290121
# 1  order "reduced chisquare" =  1.6789156516367414
# -1  order "reduced chisquare" =  5.235706590333105
# MART iteration  6  of, at most,  2000
# 0  order "reduced chisquare" =  4.428419189721357
# 1  order "reduced chisquare" =  1.2625470988768404
# -1  order "reduced chisquare" =  2.9386328876356926
# MART iteration  7  of, at most,  2000
# 0  order "reduced chisquare" =  2.895237408911314
# 1  order "reduced chisquare" =  1.0374366086032456
# -1  order "reduced chisquare" =  1.9094994313739455
# MART iteration  8  of, at most,  2000
# 0  order "reduced chisquare" =  2.2006294495316716
# 1  order "reduced chisquare" =  0.8769964896235543
# -1  order "reduced chisquare" =  1.4201586713597933
# MART iteration  9  of, at most,  2000
# 0  order "reduced chisquare" =  1.302845554873532
# 1  order "reduced chisquare" =  1.3494674918838339
# -1  order "reduced chisquare" =  0.9812456188699176
# MART iteration  10  of, at most,  2000
# 0  order "reduced chisquare" =  0.8035502916239042
# 1  order "reduced chisquare" =  0.14993000673967077
# -1  order "reduced chisquare" =  0.9812456188699176

# %%
# Plot the 'true' image, I
plt.figure(figsize=(20,20))
ax = plt.subplot(151)
plot = plt.imshow(np.sqrt(I))
plt.xlabel('$\lambda$ (pixels)')
plt.ylabel('$x$ (pixels)')
plt.title('True (sqrt scale)')
plot.set_cmap('gray')

# Plot the vanilla MART result
ax = plt.subplot(152)
plot = plt.imshow(np.sqrt(Gmart))
plt.xlabel('$\lambda$ (pixels)')
plt.ylabel('$x$ (pixels)')
plt.title('Vanilla MART')
plot.set_cmap('gray')


# Plot the initial guess
ax = plt.subplot(153)
plot = plt.imshow(np.sqrt(G_initial))
plt.xlabel('$\lambda$ (pixels)')
plt.ylabel('$x$ (pixels)')
plt.title('Suggestive Initial Guess\n(line core plus background)')
plot.set_cmap('gray')


# Plot the preconditioned MART result
ax = plt.subplot(154)
plot = plt.imshow(np.sqrt(GmartPrecon))
plt.xlabel('$\lambda$ (pixels)')
plt.ylabel('$x$ (pixels)')
plt.title('Vanilla MART with\n Suggestive Initial Guess')
plot.set_cmap('gray')

# Plot the difference
ax = plt.subplot(155)
plot = plt.imshow(GmartPrecon-I)
plt.xlabel('$\lambda$ (pixels)')
plt.ylabel('$x$ (pixels)')
plt.title('MART-True (linear)')
plot.set_cmap('gray')

# %% [markdown]
# ### Discussion
# The the linewidth of the initial guess and the magnitude of the background influence the result significantly. I have tuned these parameters to get a good looking result. There are obvious errors like the suppression of the line broadening and doppler shift at $65<x<75$.

# %% [markdown]
# ## Local Goodness-of-Fit?
# In point 4, I noted that my "$\chi^2$" is a global measure of goodness-of-fit. I guessed that MART might not bother to fit the explosive events well because they don't contribute that much to the global picture in each order. Let's see if that is correct.

# %%
# Was I right about residuals?
# Projections through the inversion, GmartPrecon:
DGm = moses.fomod(GmartPrecon, -1,j0)
DG0 = moses.fomod(GmartPrecon,  0,j0)
DGp = moses.fomod(GmartPrecon, +1,j0)

# MART works from anti-aliased outboard orders. Therefore,
# I create anti-aliased versions of the outboard orders for
# honest comparison with the corresponding projections
# through the inversion (DGm and DGp):
Dm_aa = moses.antialias(Dm)
Dp_aa = moses.antialias(Dp)

#Plot residuals
plt.figure(figsize=(20,20))
ax = plt.subplot(311)
plt.plot(Dm_aa-DGm,'b',label='residual')
plt.plot(np.sqrt(DGm),'r',label='$1\sigma$ uncertainty')
plt.plot(-np.sqrt(DGm),'r')
plt.plot(3*np.sqrt(DGm),'r:',label='$3\sigma$ uncertainty')
plt.plot(-3*np.sqrt(DGm),'r:')
plt.xlabel('$x$ (pixels)')
plt.ylabel('residual')
plt.title('$m=-1$')
plt.legend()

ax = plt.subplot(312)
plt.plot(D0-DG0,'b',label='residual')
plt.plot(np.sqrt(DG0),'r',label='$1\sigma$ uncertainty')
plt.plot(-np.sqrt(DG0),'r')
plt.plot(3*np.sqrt(DG0),'r:',label='$3\sigma$ uncertainty')
plt.plot(-3*np.sqrt(DG0),'r:')
plt.xlabel('$x$ (pixels)')
plt.ylabel('residual')
plt.title('$m=0$')
plt.legend()

ax = plt.subplot(313)
plt.plot(Dp_aa-DGp,'b',label='residual')
plt.plot(np.sqrt(DGp),'r',label='$1\sigma$ uncertainty')
plt.plot(-np.sqrt(DGp),'r')
plt.plot(3*np.sqrt(DGp),'r:',label='$3\sigma$ uncertainty')
plt.plot(-3*np.sqrt(DGp),'r:')
plt.xlabel('$x$ (pixels)')
plt.ylabel('residual')
plt.title('$m=+1$')
plt.legend()

plt.show();

# %% [markdown]
# ### Discussion
# The global goodness-of-fit fails to enforce a good fit across the whole dataset. In fact, the explosive event residuals are up to $\sim 3\sigma$, varying from run to run. This tends to support my hypothesis.
#
#
# __I have rewritten `moses.mart` use a local goodness-of-fit measure. This does not seem to result in better spectral recovery, but at least now I know that I am taking better advantage of the data in places that are difficult ot fit. The improvement can be seen by setting `LGOF=True` in the inversion for `GmartPrecon`.__
#
# A few words are in order regarding the current version of `moses.mart`.
# 1. `LGOF=False` is the default.
# 1. LGOF definitely works. But as you might expect, with such localized attention to residuals, a lot of the residuals with `LGOF=True` are at exactly $1\sigma$, which doesn't seem quite natural.
# 1. I have a first MART loop that still uses global goodness-of-fit. The LGOF loop is run after that, optionally. This seems to slightly ameliorate the above problem, and I think it does no harm.
# 1. I have increased the convergence rate a bit by doubling the exponent on the correction factor. This also helps to make the residuals look more 'noisy', hence more natural.
# 1. Anti-aliasing of the inputs is farmed out to a separate routine, `moses.antialias`, which makes it convenient to generate anti-aliased data arrays for honest comparison to projections through the inverted cube.
# 1. The examples in [Simple Plaid](SimplePlaid.ipynb) are not affected noticeably by the changes.

# %%
# Craft a very simple initial guess
InitGuess = moses.window((Nx,Nlambda))**2 # Precondition as a broad, bell-shaped window 
InitGuess = moses.mart(DataArr, mArr, Nlambda, j0, InitGuess=InitGuess, 
                      maxiter=3000, Verbose=False)

# Regularized inversion, maximizing "negentropy"
GmartNegentropy = moses.mart(DataArr, mArr, Nlambda, j0, InitGuess=InitGuess,
                      Filter=moses.contrast_smooth, Maximize=moses.negentropy, 
                      maxiter=3000, maxouter=150, Verbose=False)
# Out:
# outeration  1  of, at most,  1
# Maximize(Guess) =  -4.619999801911876
# outeration  1  of, at most,  150
# Maximize(Guess) =  -4.646295520933092
# outeration  2  of, at most,  150
# Maximize(Guess) =  -4.670590422699938
# outeration  3  of, at most,  150
# Maximize(Guess) =  -4.691903573932737
# outeration  4  of, at most,  150
# Maximize(Guess) =  -4.711504580456279
# outeration  5  of, at most,  150
# Maximize(Guess) =  -4.7267657453539895
# outeration  6  of, at most,  150
# Maximize(Guess) =  -4.7368641040573705
# outeration  7  of, at most,  150
# Maximize(Guess) =  -4.743771566609352
# outeration  8  of, at most,  150
# Maximize(Guess) =  -4.743832832218745
# outeration  9  of, at most,  150
# Maximize(Guess) =  -4.7470694317385105
# outeration  10  of, at most,  150
# Maximize(Guess) =  -4.740613583613765
# outeration  11  of, at most,  150
# Maximize(Guess) =  -4.714200155474549
# outeration  12  of, at most,  150
# Maximize(Guess) =  -4.674739093479297
# outeration  13  of, at most,  150
# Maximize(Guess) =  -4.6204515034539435
# outeration  14  of, at most,  150
# Maximize(Guess) =  -4.557808201669334
# outeration  15  of, at most,  150
# Maximize(Guess) =  -4.491042377842088
# outeration  16  of, at most,  150
# Maximize(Guess) =  -4.422803784363954
# outeration  17  of, at most,  150
# Maximize(Guess) =  -4.347192052170782
# outeration  18  of, at most,  150
# Maximize(Guess) =  -4.272302810548592
# outeration  19  of, at most,  150
# Maximize(Guess) =  -4.194320616024532
# outeration  20  of, at most,  150
# Maximize(Guess) =  -4.119917645479697
# outeration  21  of, at most,  150
# Maximize(Guess) =  -4.051004405602559
# outeration  22  of, at most,  150
# Maximize(Guess) =  -3.982591385312184
# outeration  23  of, at most,  150
# Maximize(Guess) =  -3.9106878317635694
# outeration  24  of, at most,  150
# Maximize(Guess) =  -3.8463053049101137
# outeration  25  of, at most,  150
# Maximize(Guess) =  -3.792419120132328
# outeration  26  of, at most,  150
# Maximize(Guess) =  -3.74109178640372
# outeration  27  of, at most,  150
# Maximize(Guess) =  -3.692958240503672
# outeration  28  of, at most,  150
# Maximize(Guess) =  -3.6432590109193232
# outeration  29  of, at most,  150
# Maximize(Guess) =  -3.5986185392348222
# outeration  30  of, at most,  150
# Maximize(Guess) =  -3.5643019087385013
# outeration  31  of, at most,  150
# Maximize(Guess) =  -3.538065785492005
# outeration  32  of, at most,  150
# Maximize(Guess) =  -3.5094531025364546
# outeration  33  of, at most,  150
# Maximize(Guess) =  -3.4876335118084913
# outeration  34  of, at most,  150
# Maximize(Guess) =  -3.466602340066693
# outeration  35  of, at most,  150
# Maximize(Guess) =  -3.4412739408272066
# outeration  36  of, at most,  150
# Maximize(Guess) =  -3.422216164104666
# outeration  37  of, at most,  150
# Maximize(Guess) =  -3.4138608608636236
# outeration  38  of, at most,  150
# Maximize(Guess) =  -3.4020076875023135
# outeration  39  of, at most,  150
# Maximize(Guess) =  -3.3863928379294213
# outeration  40  of, at most,  150
# Maximize(Guess) =  -3.3759669847588185
# outeration  41  of, at most,  150
# Maximize(Guess) =  -3.3631915735886233
# outeration  42  of, at most,  150
# Maximize(Guess) =  -3.353765699525352
# outeration  43  of, at most,  150
# Maximize(Guess) =  -3.346806232944966
# outeration  44  of, at most,  150
# Maximize(Guess) =  -3.3374367198652304
# outeration  45  of, at most,  150
# Maximize(Guess) =  -3.328405639878416
# outeration  46  of, at most,  150
# Maximize(Guess) =  -3.323492615425732
# outeration  47  of, at most,  150
# Maximize(Guess) =  -3.319035019939053
# outeration  48  of, at most,  150
# Maximize(Guess) =  -3.312847852271775
# outeration  49  of, at most,  150
# Maximize(Guess) =  -3.3089144200541925
# outeration  50  of, at most,  150
# Maximize(Guess) =  -3.306101512312423
# outeration  51  of, at most,  150
# Maximize(Guess) =  -3.301774884854298
# outeration  52  of, at most,  150
# Maximize(Guess) =  -3.2993899147081116
# outeration  53  of, at most,  150
# Maximize(Guess) =  -3.296733734237625
# outeration  54  of, at most,  150
# Maximize(Guess) =  -3.294020472886354
# outeration  55  of, at most,  150
# Maximize(Guess) =  -3.2918770351968587
# outeration  56  of, at most,  150
# Maximize(Guess) =  -3.2902356452631967
# outeration  57  of, at most,  150
# Maximize(Guess) =  -3.2905062228242237
# outeration  58  of, at most,  150
# Maximize(Guess) =  -3.289339184130201
# outeration  59  of, at most,  150
# Maximize(Guess) =  -3.289262431240431
# outeration  60  of, at most,  150
# Maximize(Guess) =  -3.2863675270510635
# outeration  61  of, at most,  150
# Maximize(Guess) =  -3.2856042567659927
# outeration  62  of, at most,  150
# Maximize(Guess) =  -3.2858649586085225
# outeration  63  of, at most,  150
# Maximize(Guess) =  -3.2851208872531217
# outeration  64  of, at most,  150
# Maximize(Guess) =  -3.2837989420845513
# outeration  65  of, at most,  150
# Maximize(Guess) =  -3.2833589144260045
# outeration  66  of, at most,  150
# Maximize(Guess) =  -3.2834073449374817
# outeration  67  of, at most,  150
# Maximize(Guess) =  -3.283215339005418
# outeration  68  of, at most,  150
# Maximize(Guess) =  -3.282506537212129
# outeration  69  of, at most,  150
# Maximize(Guess) =  -3.2807741997683086
# outeration  70  of, at most,  150
# Maximize(Guess) =  -3.2812136807162324
# outeration  71  of, at most,  150
# Maximize(Guess) =  -3.2791109850388964
# outeration  72  of, at most,  150
# Maximize(Guess) =  -3.2793093683682724
# outeration  73  of, at most,  150
# Maximize(Guess) =  -3.2791592828305385
# outeration  74  of, at most,  150
# Maximize(Guess) =  -3.2798208043821715
# outeration  75  of, at most,  150
# Maximize(Guess) =  -3.2791362310445535
# outeration  76  of, at most,  150
# Maximize(Guess) =  -3.2793192874523056
# outeration  77  of, at most,  150
# Maximize(Guess) =  -3.2793416034462655
# outeration  78  of, at most,  150
# Maximize(Guess) =  -3.2781769305311466
# outeration  79  of, at most,  150
# Maximize(Guess) =  -3.2794403083178585
# outeration  80  of, at most,  150
# Maximize(Guess) =  -3.27973624212925
# outeration  81  of, at most,  150
# Maximize(Guess) =  -3.279328817681925
# outeration  82  of, at most,  150
# Maximize(Guess) =  -3.279543587655883
# outeration  83  of, at most,  150
# Maximize(Guess) =  -3.279624259130327
# outeration  84  of, at most,  150
# Maximize(Guess) =  -3.2793799365656153
# outeration  85  of, at most,  150
# Maximize(Guess) =  -3.279341752310173
# outeration  86  of, at most,  150
# Maximize(Guess) =  -3.2795397595767946
# outeration  87  of, at most,  150
# Maximize(Guess) =  -3.2799783994387184
# outeration  88  of, at most,  150
# Maximize(Guess) =  -3.279745489580777
# outeration  89  of, at most,  150
# Maximize(Guess) =  -3.2788147629651516
# outeration  90  of, at most,  150
# Maximize(Guess) =  -3.2790288317151695
# outeration  91  of, at most,  150
# Maximize(Guess) =  -3.2786792306610466
# outeration  92  of, at most,  150
# Maximize(Guess) =  -3.2787920848266046
# outeration  93  of, at most,  150
# Maximize(Guess) =  -3.2787655032308467
# outeration  94  of, at most,  150
# Maximize(Guess) =  -3.2788170366377534
# outeration  95  of, at most,  150
# Maximize(Guess) =  -3.2789484638683417
# outeration  96  of, at most,  150
# Maximize(Guess) =  -3.278383160745192
# outeration  97  of, at most,  150
# Maximize(Guess) =  -3.2773644788476757
# outeration  98  of, at most,  150
# Maximize(Guess) =  -3.2771376543461743
# outeration  99  of, at most,  150
# Maximize(Guess) =  -3.276996776443649
# outeration  100  of, at most,  150
# Maximize(Guess) =  -3.2778542153844246
# outeration  101  of, at most,  150
# Maximize(Guess) =  -3.2779675064594787
# outeration  102  of, at most,  150
# Maximize(Guess) =  -3.2780847688308046
# outeration  103  of, at most,  150
# Maximize(Guess) =  -3.278105549641589
# outeration  104  of, at most,  150
# Maximize(Guess) =  -3.2781027365551845
# outeration  105  of, at most,  150
# Maximize(Guess) =  -3.2776330074453366
# outeration  106  of, at most,  150
# Maximize(Guess) =  -3.27662014219777
# outeration  107  of, at most,  150
# Maximize(Guess) =  -3.276434152669909
# outeration  108  of, at most,  150
# Maximize(Guess) =  -3.276540314718953
# outeration  109  of, at most,  150
# Maximize(Guess) =  -3.2777326454651874
# outeration  110  of, at most,  150
# Maximize(Guess) =  -3.2777402348453233
# outeration  111  of, at most,  150
# Maximize(Guess) =  -3.2778273941444898
# outeration  112  of, at most,  150
# Maximize(Guess) =  -3.2771961051172367
# outeration  113  of, at most,  150
# Maximize(Guess) =  -3.2772603529293614
# outeration  114  of, at most,  150
# Maximize(Guess) =  -3.2770567245661546
# outeration  115  of, at most,  150
# Maximize(Guess) =  -3.2772673967267485
# outeration  116  of, at most,  150
# Maximize(Guess) =  -3.277884009488988
# outeration  117  of, at most,  150
# Maximize(Guess) =  -3.277011072870264
# outeration  118  of, at most,  150
# Maximize(Guess) =  -3.2768616763457143
# outeration  119  of, at most,  150
# Maximize(Guess) =  -3.2770309374945255
# outeration  120  of, at most,  150
# Maximize(Guess) =  -3.2768485207545583
# outeration  121  of, at most,  150
# Maximize(Guess) =  -3.2772203117504404
# outeration  122  of, at most,  150
# Maximize(Guess) =  -3.277020629251802
# outeration  123  of, at most,  150
# Maximize(Guess) =  -3.2772058617973197
# outeration  124  of, at most,  150
# Maximize(Guess) =  -3.2772568012887446
# outeration  125  of, at most,  150
# Maximize(Guess) =  -3.2773904173865707
# outeration  126  of, at most,  150
# Maximize(Guess) =  -3.2771839483643803
# outeration  127  of, at most,  150
# Maximize(Guess) =  -3.2771415515524582
# outeration  128  of, at most,  150
# Maximize(Guess) =  -3.2758252687667175
# outeration  129  of, at most,  150
# Maximize(Guess) =  -3.2764019920543017
# outeration  130  of, at most,  150
# Maximize(Guess) =  -3.276023322045591
# outeration  131  of, at most,  150
# Maximize(Guess) =  -3.2751374295736926
# outeration  132  of, at most,  150
# Maximize(Guess) =  -3.2750822309515977
# outeration  133  of, at most,  150
# Maximize(Guess) =  -3.273886959370638
# outeration  134  of, at most,  150
# Maximize(Guess) =  -3.274498323899905
# outeration  135  of, at most,  150
# Maximize(Guess) =  -3.2757786288930864
# outeration  136  of, at most,  150
# Maximize(Guess) =  -3.2755186535895837
# outeration  137  of, at most,  150
# Maximize(Guess) =  -3.2750781265209623
# outeration  138  of, at most,  150
# Maximize(Guess) =  -3.2749822917823077
# outeration  139  of, at most,  150
# Maximize(Guess) =  -3.273580053509984
# outeration  140  of, at most,  150
# Maximize(Guess) =  -3.2739533174645423
# outeration  141  of, at most,  150
# Maximize(Guess) =  -3.2737794043142734
# outeration  142  of, at most,  150
# Maximize(Guess) =  -3.2743992878508457
# outeration  143  of, at most,  150
# Maximize(Guess) =  -3.2748800457440685
# outeration  144  of, at most,  150
# Maximize(Guess) =  -3.2750971480999245
# outeration  145  of, at most,  150
# Maximize(Guess) =  -3.275634133647068
# outeration  146  of, at most,  150
# Maximize(Guess) =  -3.2753620764416063
# outeration  147  of, at most,  150
# Maximize(Guess) =  -3.2757455849340706
# outeration  148  of, at most,  150
# Maximize(Guess) =  -3.2750965786814485
# outeration  149  of, at most,  150
# Maximize(Guess) =  -3.276167367262998
# outeration  150  of, at most,  150
# Best result, Maximize(Guess) =  -3.273580053509984 , was obtained on outeration  139

# %%
# Plot the 'true' image, I
plt.figure(figsize=(20,20))
ax = plt.subplot(141)
plot = plt.imshow(np.sqrt(I))
plt.xlabel('$\lambda$ (pixels)')
plt.ylabel('$x$ (pixels)')
plt.title('True (sqrt scale)')
plot.set_cmap('gray')

# Plot the initial guess
ax = plt.subplot(142)
plot = plt.imshow(np.sqrt(InitGuess))
plt.xlabel('$\lambda$ (pixels)')
plt.ylabel('$x$ (pixels)')
plt.title('Initial Guess')
plot.set_cmap('gray')


# Plot the regularized MART result
ax = plt.subplot(143)
plot = plt.imshow(np.sqrt(GmartNegentropy))
plt.xlabel('$\lambda$ (pixels)')
plt.ylabel('$x$ (pixels)')
plt.title('Regularized MART')
plot.set_cmap('gray')

# Plot the difference
ax = plt.subplot(144)
plot = plt.imshow(np.concatenate( (InitGuess-I, GmartNegentropy-I), axis=1))
plt.xlabel('$\lambda$ (pixels)')
plt.ylabel('$x$ (pixels)')
plt.title('Init-True;           MART-True\n (linear scale)')
plot.set_cmap('gray')

# %% [markdown]
# ### Discussion
# 1. I have obtained a reasonably smooth result with minimized entropy using a regularization scheme similar to that developed for [the Simple Plaid notebook](SimplePlaid.ipynb).
# 1. The regularization takes a lot of outeration loops to find the lowest entropy. I tried to make it faster by using a bigger contrast power $p$ in the filter, but the resulting increase in _iterations_ required for MART to converge seems to more than make up for the savings in _outerations_.
# 1. I added iterative smoothing into the filter (`moses.contrast_smooth`) to avoid shrinking the line profile to a single pixel and/or getting strong spatial discontinuities.
# 1. The amount of smoothing is arbitrary, and it does matter, so this constitutes a new adjustable parameter.
# 1. __This regularization eliminates the plaid successfully. Hurray!__
# 1. Broadening at $65<x<75$ appears marginally improved compared to `GmartPrecon`, but the residuals may be a little larger.
# 1. Fit to the EE at $x \sim 25$ is markedly worse than `GmartPrecon`.
# 1. `LGOF` is off (by default), to save iterations. Turning it on doesn't make a noticeable difference in the result.
# 1. Results are similar with other explosive events, which can easily be subbed in to this notebook.
