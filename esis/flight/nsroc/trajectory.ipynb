# %%
import matplotlib.pyplot as plt
import pandas
from esis.flight import nsroc

# %%
# %matplotlib notebook

# %%
pandas.set_option('display.max_columns', 500)

# %%
trajectory = nsroc.trajectory()

# %%
fig_alt, ax_alt = plt.subplots(figsize=(9.5, 5), constrained_layout=True)
ax_vel = ax_alt.twinx()
trajectory.plot_altitude_and_velocity_vs_time(ax_altitude=ax_alt, ax_velocity=ax_vel);
# Out:
# <img src="data:image/png;base64,..." width="949.6">
